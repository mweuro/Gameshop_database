# %%
import numpy as np
import pandas as pd
import math
from selenium import webdriver
from selenium.webdriver.edge.service import Service
from selenium.webdriver.edge.options import Options

import json
from bs4 import BeautifulSoup
import requests
import re

# %%
"""Finds a description for each game in the dataset. Applies it to a dataframe."""
def find_description(df):
    url_list = df.bgg_url.values
    descriptions = []
    for url in url_list:
        response = requests.get(url)
        response.raise_for_status()
        html_content = response.text
        soup = BeautifulSoup(html_content, 'html.parser')
        script_element = soup.find('script', type='application/ld+json').string
        data = json.loads(script_element)
        description = data.get('description')
        descriptions.append(description)
    df.insert(4, 'description', descriptions)
    return df

# %%
df2 = pd.read_csv('boardgames.csv', sep = ',')
df2
# Out:
#       rank                                            bgg_url  game_id  \
# 0        1  https://boardgamegeek.com/boardgame/174430/glo...   174430
# 1        2  https://boardgamegeek.com/boardgame/161936/pan...   161936
# 2        3  https://boardgamegeek.com/boardgame/182028/thr...   182028
# 3        4  https://boardgamegeek.com/boardgame/167791/ter...   167791
# 4        5  https://boardgamegeek.com/boardgame/12333/twil...    12333
# ...    ...                                                ...      ...
# 4994  4995  https://boardgamegeek.com/boardgame/6569/cronberg     6569
# 4995  4996  https://boardgamegeek.com/boardgame/42713/arca...    42713
# 4996  4997  https://boardgamegeek.com/boardgame/836/new-en...      836
# 4997  4998  https://boardgamegeek.com/boardgame/2997/soldi...     2997
# 4998  4999  https://boardgamegeek.com/boardgame/128174/dra...   128174
#
#                                               names  \
# 0                                        Gloomhaven
# 1                         Pandemic Legacy: Season 1
# 2     Through the Ages: A New Story of Civilization
# 3                                 Terraforming Mars
# 4                                 Twilight Struggle
# ...                                             ...
# 4994                                       Cronberg
# 4995                                 Arcane Legions
# 4996                           New England Railways
# 4997                                  Soldier Kings
# 4998                                  Dragon Farkle
#
#                                             description  min_players  \
# 0     Vanquish monsters with strategic cardplay. Ful...            1
# 1     Mutating diseases are spreading around the wor...            2
# 2     Rewrite history as you build up your civilizat...            2
# 3     Compete with rival CEOs to make Mars habitable...            1
# 4     Relive the Cold War and rewrite history in an ...            2
# ...                                                 ...          ...
# 4994                                                NaN            2
# 4995                                                NaN            2
# 4996                                                NaN            3
# 4997                                                NaN            2
# 4998           Dice, companions, and a dragon, oh my...            2
#
#       max_players  avg_time  min_time  max_time  ...  avg_rating  geek_rating  \
# 0               4       120        60       120  ...     8.98893      8.61858
# 1               4        60        60        60  ...     8.66140      8.50163
# 2               4       240       180       240  ...     8.60673      8.30183
# 3               5       120       120       120  ...     8.38461      8.19914
# 4               2       180       120       180  ...     8.33954      8.19787
# ...           ...       ...       ...       ...  ...         ...          ...
# 4994            4        20        20        20  ...     5.99954      5.64032
# 4995            6       120        60       120  ...     6.39838      5.64030
# 4996            6       120       120       120  ...     6.71815      5.64026
# 4997            8       240       240       240  ...     6.36062      5.64024
# 4998            5        30        30        30  ...     6.29081      5.64024
#
#       num_votes                                          image_url age  \
# 0         15376  https://cf.geekdo-images.com/original/img/lDN3...  12
# 1         26063  https://cf.geekdo-images.com/original/img/P_Sw...  13
# 2         12352  https://cf.geekdo-images.com/original/img/1d2h...  14
# 3         26004  https://cf.geekdo-images.com/original/img/o8z_...  12
# 4         31301  https://cf.geekdo-images.com/original/img/ZPnn...  13
# ...         ...                                                ...  ..
# 4994        456  https://cf.geekdo-images.com/original/img/pBmQ...   8
# 4995        277  https://cf.geekdo-images.com/original/img/Ea2O...  10
# 4996        146  https://cf.geekdo-images.com/original/img/2EXT...  13
# 4997        257  https://cf.geekdo-images.com/original/img/eNqF...  14
# 4998        283  https://cf.geekdo-images.com/original/img/7iS6...  13
#
#                                                mechanic  owned  \
# 0     Action / Movement Programming, Co-operative Pl...  25928
# 1     Action Point Allowance System, Co-operative Pl...  41605
# 2     Action Point Allowance System, Auction/Bidding...  15848
# 3     Card Drafting, Hand Management, Set Collection...  33340
# 4     Area Control / Area Influence, Campaign / Batt...  42952
# ...                                                 ...    ...
# 4994                     Area Enclosure, Tile Placement    561
# 4995  Action Point Allowance System, Dice Rolling, V...    825
# 4996               Auction/Bidding, Pick-up and Deliver    440
# 4997    Point to Point Movement, Variable Player Powers    659
# 4998                        Card Drafting, Dice Rolling    629
#
#                                                category  \
# 0     Adventure, Exploration, Fantasy, Fighting, Min...
# 1                                Environmental, Medical
# 2                     Card Game, Civilization, Economic
# 3     Economic, Environmental, Industry / Manufactur...
# 4                    Modern Warfare, Political, Wargame
# ...                                                 ...
# 4994                        City Building, Print & Play
# 4995  Ancient, Collectible Components, Dice, Fantasy...
# 4996                                   Economic, Trains
# 4997                             Age of Reason, Wargame
# 4998                                            Fantasy
#
#                                                designer  weight
# 0                                        Isaac Childres  3.7543
# 1                              Rob Daviau, Matt Leacock  2.8210
# 2                                        Vlaada Chvátil  4.3678
# 3                                       Jacob Fryxelius  3.2456
# 4                          Ananda Gupta, Jason Matthews  3.5518
# ...                                                 ...     ...
# 4994                       Tobias Goslar, Roland Goslar  1.9074
# 4995  Tyler Bielman, Jonathon Loucks, Ethan Pasterna...  2.3750
# 4996                        John Bohrer, Martin Wallace  2.6250
# 4997                                  Robert G. Markham  2.4359
# 4998                                  Robert J. Hudecek  1.6000
#
# [4999 rows x 21 columns]

# %%
"""Finds a price for each game in the dataset. Applies it to a dataframe."""
def find_price(df):
    url_list = df.bgg_url.values
    prices = np.zeros(len(url_list))
    
    driver_path = r"C:\Users\20meh\EdgeWebDriver\msedgedriver.exe"
    options = Options()
    options.add_argument('--headless')
    service = Service(driver_path)
    for i in range(len(url_list) - 1):
        driver = webdriver.Edge(service=service, options=options)
        driver.get(url_list[i])
        html = driver.page_source
        driver.quit()
        soup = BeautifulSoup(html, 'html.parser')
        try:
            price_block = soup.find('li', class_ = 'summary-item summary-sale-item ng-scope')
            price = price_block.find('strong', class_ = 'ng-binding').string.replace(',', '.')
            price = float(re.findall(r"\d+\.\d+", price)[0])
        except:
            price_block = soup.find_all('li', class_ = 'summary-item summary-sale-item ng-scope')[1]
            price = price_block.find('strong', class_ = 'ng-binding').string.replace(',', '.')
            try:
                price = float(re.findall(r"\d+\.\d+", price)[0])
            except:
                price = None
        prices[i] = price
    df_copy = df.copy()
    df_copy['price'] = prices
    return df_copy

# %%
df3 = find_price(df2.head(10))
df3
# Out:
#    rank                                            bgg_url  game_id  \
# 0     1  https://boardgamegeek.com/boardgame/174430/glo...   174430
# 1     2  https://boardgamegeek.com/boardgame/161936/pan...   161936
# 2     3  https://boardgamegeek.com/boardgame/182028/thr...   182028
# 3     4  https://boardgamegeek.com/boardgame/167791/ter...   167791
# 4     5  https://boardgamegeek.com/boardgame/12333/twil...    12333
# 5     6  https://boardgamegeek.com/boardgame/187645/sta...   187645
# 6     7  https://boardgamegeek.com/boardgame/169786/scythe   169786
# 7     8  https://boardgamegeek.com/boardgame/120677/ter...   120677
# 8     9  https://boardgamegeek.com/boardgame/193738/gre...   193738
# 9    10  https://boardgamegeek.com/boardgame/180263/7th...   180263
#
#                                            names  \
# 0                                     Gloomhaven
# 1                      Pandemic Legacy: Season 1
# 2  Through the Ages: A New Story of Civilization
# 3                              Terraforming Mars
# 4                              Twilight Struggle
# 5                           Star Wars: Rebellion
# 6                                         Scythe
# 7                                  Terra Mystica
# 8                            Great Western Trail
# 9                              The 7th Continent
#
#                                          description  min_players  \
# 0  Vanquish monsters with strategic cardplay. Ful...            1
# 1  Mutating diseases are spreading around the wor...            2
# 2  Rewrite history as you build up your civilizat...            2
# 3  Compete with rival CEOs to make Mars habitable...            1
# 4  Relive the Cold War and rewrite history in an ...            2
# 5  Strike from your hidden base as the Rebels—or ...            2
# 6  Five factions vie for dominance in a war-torn,...            1
# 7  Play fantastical factions.  Expand your influe...            2
# 8  Use strategic outposts and navigate danger as ...            2
# 9  Journey through a vibrant but deadly land to u...            1
#
#    max_players  avg_time  min_time  max_time  ...  geek_rating  num_votes  \
# 0            4       120        60       120  ...      8.61858      15376
# 1            4        60        60        60  ...      8.50163      26063
# 2            4       240       180       240  ...      8.30183      12352
# 3            5       120       120       120  ...      8.19914      26004
# 4            2       180       120       180  ...      8.19787      31301
# 5            4       240       180       240  ...      8.16545      13336
# 6            5       115        90       115  ...      8.10800      29219
# 7            5       150        60       150  ...      8.09296      29309
# 8            4       150        75       150  ...      8.04047      13521
# 9            4      1000         5      1000  ...      8.02458       6057
#
#                                            image_url  age  \
# 0  https://cf.geekdo-images.com/original/img/lDN3...   12
# 1  https://cf.geekdo-images.com/original/img/P_Sw...   13
# 2  https://cf.geekdo-images.com/original/img/1d2h...   14
# 3  https://cf.geekdo-images.com/original/img/o8z_...   12
# 4  https://cf.geekdo-images.com/original/img/ZPnn...   13
# 5  https://cf.geekdo-images.com/original/img/QT95...   14
# 6  https://cf.geekdo-images.com/original/img/enxC...   14
# 7  https://cf.geekdo-images.com/original/img/Cynj...   12
# 8  https://cf.geekdo-images.com/original/img/U3Rn...   12
# 9  https://cf.geekdo-images.com/original/img/iQDB...   14
#
#                                             mechanic  owned  \
# 0  Action / Movement Programming, Co-operative Pl...  25928
# 1  Action Point Allowance System, Co-operative Pl...  41605
# 2  Action Point Allowance System, Auction/Bidding...  15848
# 3  Card Drafting, Hand Management, Set Collection...  33340
# 4  Area Control / Area Influence, Campaign / Batt...  42952
# 5  Area Control / Area Influence, Area Movement, ...  20682
# 6  Area Control / Area Influence, Grid Movement, ...  38279
# 7  Area Control / Area Influence, Route/Network B...  32637
# 8  Deck / Pool Building, Hand Management, Point t...  16869
# 9  Co-operative Play, Grid Movement, Hand Managem...  12543
#
#                                             category  \
# 0  Adventure, Exploration, Fantasy, Fighting, Min...
# 1                             Environmental, Medical
# 2                  Card Game, Civilization, Economic
# 3  Economic, Environmental, Industry / Manufactur...
# 4                 Modern Warfare, Political, Wargame
# 5  Fighting, Miniatures, Movies / TV / Radio them...
# 6  Civilization, Economic, Fighting, Miniatures, ...
# 7  Civilization, Economic, Fantasy, Territory Bui...
# 8                                      American West
# 9  Adventure, Card Game, Exploration, Horror, Sci...
#
#                            designer  weight   price
# 0                    Isaac Childres  3.7543  155.98
# 1          Rob Daviau, Matt Leacock  2.8210   60.89
# 2                    Vlaada Chvátil  4.3678   66.18
# 3                   Jacob Fryxelius  3.2456   78.92
# 4      Ananda Gupta, Jason Matthews  3.5518   54.95
# 5                   Corey Konieczka  3.6311  107.79
# 6                   Jamey Stegmaier  3.3609   78.78
# 7  Jens Drögemüller, Helge Ostertag  3.9505   54.99
# 8                 Alexander Pfister  3.7011   37.99
# 9      Ludovic Roudy, Bruno Sautter  2.8578    0.00
#
# [10 rows x 22 columns]
