# %%
import numpy as np
import pandas as pd
import math
from selenium import webdriver
from selenium.webdriver.edge.service import Service
from selenium.webdriver.edge.options import Options

import json
from bs4 import BeautifulSoup
import requests
import re

# %%
"""Finds a description for each game in the dataset. Applies it to a dataframe."""
def find_description(df):
    url_list = df.bgg_url.values
    descriptions = []
    for url in url_list:
        response = requests.get(url)
        response.raise_for_status()
        html_content = response.text
        soup = BeautifulSoup(html_content, 'html.parser')
        script_element = soup.find('script', type='application/ld+json').string
        data = json.loads(script_element)
        description = data.get('description')
        descriptions.append(description)
    df.insert(4, 'description', descriptions)
    return df

# %%
df2 = pd.read_csv('boardgames.csv', sep = ',')

# %%
"""Finds a price for each game in the dataset. Applies it to a dataframe."""
def find_price(df):
    url_list = df.bgg_url.values
    prices = np.zeros(len(url_list))
    
    driver_path = r"C:\Users\20meh\EdgeWebDriver\msedgedriver.exe"
    options = Options()
    options.add_argument('--headless')
    service = Service(driver_path)
    for i in range(len(url_list)):
        driver = webdriver.Edge(service=service, options=options)
        driver.get(url_list[i])
        html = driver.page_source
        driver.quit()
        soup = BeautifulSoup(html, 'html.parser')
        try:
            price_block = soup.find('li', class_ = 'summary-item summary-sale-item ng-scope')
            price = price_block.find('strong', class_ = 'ng-binding').string.replace(',', '.')
            price = float(re.findall(r"\d+\.\d+", price)[0])
        except:
            try:
                price_block = soup.find_all('li', class_ = 'summary-item summary-sale-item ng-scope')[1]
                price = price_block.find('strong', class_ = 'ng-binding').string.replace(',', '.')
                price = float(re.findall(r"\d+\.\d+", price)[0])
            except:
                price = None
        prices[i] = price
    df_copy = df.copy()
    df_copy['price'] = prices
    return df_copy

# %%
df3 = find_price(df2)
df3
# Out:
#       rank                                            bgg_url  game_id  \
# 0        1  https://boardgamegeek.com/boardgame/174430/glo...   174430
# 1        2  https://boardgamegeek.com/boardgame/161936/pan...   161936
# 2        3  https://boardgamegeek.com/boardgame/182028/thr...   182028
# 3        4  https://boardgamegeek.com/boardgame/167791/ter...   167791
# 4        5  https://boardgamegeek.com/boardgame/12333/twil...    12333
# ...    ...                                                ...      ...
# 4994  4995  https://boardgamegeek.com/boardgame/6569/cronberg     6569
# 4995  4996  https://boardgamegeek.com/boardgame/42713/arca...    42713
# 4996  4997  https://boardgamegeek.com/boardgame/836/new-en...      836
# 4997  4998  https://boardgamegeek.com/boardgame/2997/soldi...     2997
# 4998  4999  https://boardgamegeek.com/boardgame/128174/dra...   128174
#
#                                               names  \
# 0                                        Gloomhaven
# 1                         Pandemic Legacy: Season 1
# 2     Through the Ages: A New Story of Civilization
# 3                                 Terraforming Mars
# 4                                 Twilight Struggle
# ...                                             ...
# 4994                                       Cronberg
# 4995                                 Arcane Legions
# 4996                           New England Railways
# 4997                                  Soldier Kings
# 4998                                  Dragon Farkle
#
#                                             description  min_players  \
# 0     Vanquish monsters with strategic cardplay. Ful...            1
# 1     Mutating diseases are spreading around the wor...            2
# 2     Rewrite history as you build up your civilizat...            2
# 3     Compete with rival CEOs to make Mars habitable...            1
# 4     Relive the Cold War and rewrite history in an ...            2
# ...                                                 ...          ...
# 4994                                                NaN            2
# 4995                                                NaN            2
# 4996                                                NaN            3
# 4997                                                NaN            2
# 4998           Dice, companions, and a dragon, oh my...            2
#
#       max_players  avg_time  min_time  max_time  ...  geek_rating  num_votes  \
# 0               4       120        60       120  ...      8.61858      15376
# 1               4        60        60        60  ...      8.50163      26063
# 2               4       240       180       240  ...      8.30183      12352
# 3               5       120       120       120  ...      8.19914      26004
# 4               2       180       120       180  ...      8.19787      31301
# ...           ...       ...       ...       ...  ...          ...        ...
# 4994            4        20        20        20  ...      5.64032        456
# 4995            6       120        60       120  ...      5.64030        277
# 4996            6       120       120       120  ...      5.64026        146
# 4997            8       240       240       240  ...      5.64024        257
# 4998            5        30        30        30  ...      5.64024        283
#
#                                               image_url  age  \
# 0     https://cf.geekdo-images.com/original/img/lDN3...   12
# 1     https://cf.geekdo-images.com/original/img/P_Sw...   13
# 2     https://cf.geekdo-images.com/original/img/1d2h...   14
# 3     https://cf.geekdo-images.com/original/img/o8z_...   12
# 4     https://cf.geekdo-images.com/original/img/ZPnn...   13
# ...                                                 ...  ...
# 4994  https://cf.geekdo-images.com/original/img/pBmQ...    8
# 4995  https://cf.geekdo-images.com/original/img/Ea2O...   10
# 4996  https://cf.geekdo-images.com/original/img/2EXT...   13
# 4997  https://cf.geekdo-images.com/original/img/eNqF...   14
# 4998  https://cf.geekdo-images.com/original/img/7iS6...   13
#
#                                                mechanic  owned  \
# 0     Action / Movement Programming, Co-operative Pl...  25928
# 1     Action Point Allowance System, Co-operative Pl...  41605
# 2     Action Point Allowance System, Auction/Bidding...  15848
# 3     Card Drafting, Hand Management, Set Collection...  33340
# 4     Area Control / Area Influence, Campaign / Batt...  42952
# ...                                                 ...    ...
# 4994                     Area Enclosure, Tile Placement    561
# 4995  Action Point Allowance System, Dice Rolling, V...    825
# 4996               Auction/Bidding, Pick-up and Deliver    440
# 4997    Point to Point Movement, Variable Player Powers    659
# 4998                        Card Drafting, Dice Rolling    629
#
#                                                category  \
# 0     Adventure, Exploration, Fantasy, Fighting, Min...
# 1                                Environmental, Medical
# 2                     Card Game, Civilization, Economic
# 3     Economic, Environmental, Industry / Manufactur...
# 4                    Modern Warfare, Political, Wargame
# ...                                                 ...
# 4994                        City Building, Print & Play
# 4995  Ancient, Collectible Components, Dice, Fantasy...
# 4996                                   Economic, Trains
# 4997                             Age of Reason, Wargame
# 4998                                            Fantasy
#
#                                                designer  weight   price
# 0                                        Isaac Childres  3.7543  155.98
# 1                              Rob Daviau, Matt Leacock  2.8210   60.89
# 2                                        Vlaada Chvátil  4.3678   66.18
# 3                                       Jacob Fryxelius  3.2456   78.92
# 4                          Ananda Gupta, Jason Matthews  3.5518   54.95
# ...                                                 ...     ...     ...
# 4994                       Tobias Goslar, Roland Goslar  1.9074   20.00
# 4995  Tyler Bielman, Jonathon Loucks, Ethan Pasterna...  2.3750   29.95
# 4996                        John Bohrer, Martin Wallace  2.6250   22.00
# 4997                                  Robert G. Markham  2.4359   11.00
# 4998                                  Robert J. Hudecek  1.6000   25.93
#
# [4999 rows x 22 columns]

# %%
df3.to_csv('boardgames_sale.csv', index = False)
