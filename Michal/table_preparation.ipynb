# %%
import pandas as pd
import numpy as np
from random import randint

# %%
df = pd.read_csv('boardgames_sale.csv')
df.head()
# Out:
#    rank                                            bgg_url  game_id  \
# 0     1  https://boardgamegeek.com/boardgame/174430/glo...   174430
# 1     2  https://boardgamegeek.com/boardgame/161936/pan...   161936
# 2     3  https://boardgamegeek.com/boardgame/182028/thr...   182028
# 3     4  https://boardgamegeek.com/boardgame/167791/ter...   167791
# 4     5  https://boardgamegeek.com/boardgame/12333/twil...    12333
#
#                                            names  \
# 0                                     Gloomhaven
# 1                      Pandemic Legacy: Season 1
# 2  Through the Ages: A New Story of Civilization
# 3                              Terraforming Mars
# 4                              Twilight Struggle
#
#                                          description  min_players  \
# 0  Vanquish monsters with strategic cardplay. Ful...            1
# 1  Mutating diseases are spreading around the wor...            2
# ...

# %% [markdown]
# ## Games for sale

# %%
sale = df.drop(['rank', 'bgg_url', 'min_time', 'max_time', 'geek_rating', 'num_votes', 'image_url', 'designer', 'weight'], axis = 1)
sale = sale[sale.price.isnull() == False].reset_index(drop = True)
sale.price = round(sale.price * 4.44, 2)
sale.head()
# Out:
#    game_id                                          names  \
# 0   174430                                     Gloomhaven
# 1   161936                      Pandemic Legacy: Season 1
# 2   182028  Through the Ages: A New Story of Civilization
# 3   167791                              Terraforming Mars
# 4    12333                              Twilight Struggle
#
#                                          description  min_players  \
# 0  Vanquish monsters with strategic cardplay. Ful...            1
# 1  Mutating diseases are spreading around the wor...            2
# 2  Rewrite history as you build up your civilizat...            2
# 3  Compete with rival CEOs to make Mars habitable...            1
# 4  Relive the Cold War and rewrite history in an ...            2
#
#    max_players  avg_time  year  avg_rating  age  \
# 0            4       120  2017     8.98893   12
# 1            4        60  2015     8.66140   13
# 2            4       240  2015     8.60673   14
# ...

# %% [markdown]
# ## Games to rent

# %%
"""Generates list of random integers (from 0 to 10), with advantage of zeros."""
def games_count(n = np.shape(sale)[0]):
    a = [randint(0, 10) for i in range(n)]
    b = [0 if randint(0, len(a)) < 500 else i for i in a]
    return b

# %%
rent = sale[['game_id', 'price', 'min_players', 'max_players']]

# %%
price = rent.price.values
rent_price = []
for price in price:
    if 0 <= price < 100:
        p = 2
    elif 100 <= price < 500:
        p = 5
    elif 500 <= price < 1000:
        p = 10
    elif 1000 <= price < 1500:
        p = 15
    else:
        p = 20
    rent_price.append(p)

# %%
rent2 = rent.copy()
rent2['rent_price'] = rent_price
rent2 = rent2.drop(['price'], axis = 1)
rent2 = rent2.loc[rent2.index.repeat(games_count())].reset_index(drop = True)
rent2.insert(0, 'item_id', np.array([*range(len(rent2))]) + 1)
rent2
# Out:
#        item_id  game_id  min_players  max_players  rent_price
# 0            1   174430            1            4          10
# 1            2   174430            1            4          10
# 2            3   174430            1            4          10
# 3            4   174430            1            4          10
# 4            5   174430            1            4          10
# ...        ...      ...          ...          ...         ...
# 15937    15938    42713            2            6           5
# 15938    15939    42713            2            6           5
# 15939    15940    42713            2            6           5
# 15940    15941      836            3            6           2
# 15941    15942      836            3            6           2
#
# [15942 rows x 5 columns]

# %%
sale.to_csv('../database/games_for_sale.csv', index = False)
rent2.to_csv('../database/games_to_rent.csv', index = False)
