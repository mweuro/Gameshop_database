# %%
import pandas as pd
import numpy as np
import random, string
from collections import Counter
from unidecode import unidecode

# %% [markdown]
# # customer table

# %%
random.seed(123)
n = 1329 #ilość klientów

# %% [markdown]
# GUS: https://dane.gov.pl/pl/dataset/219,imiona-nadawane-dzieciom-w-polsce/resource/44824/table?page=1&per_page=20&q=&sort=

# %%
n_k = pd.read_csv('nazwiska_k.csv', sep = ",")
n_m = pd.read_csv('nazwiska_m.csv', sep = ",")
i_k = pd.read_csv('imiona_k.csv', sep = ",")
i_k = i_k.rename(columns={'LICZBA WYSTĄPIENIEŃ': 'Liczba'})
i_m = pd.read_csv('imiona_m.csv', sep = ",")
i_m = i_m.rename(columns={'LICZBA WYSTĄPIEŃ': 'Liczba'})

# %%
N_k = [n_k["Nazwisko aktualne"][i].lower().capitalize() for i in range(150000)]
N_m = [n_m["Nazwisko aktualne"][i].lower().capitalize() for i in range(150000)]
I_k = [i_k["IMIĘ PIERWSZE"][i].lower().capitalize() for i in range(i_k.shape[0])]
I_m = [i_m["IMIĘ PIERWSZE"][i].lower().capitalize() for i in range(i_m.shape[0])]

# %% [raw]
# ilość mieszkańców Wrocławia: 674 079
# ilość kobiet: 359537 (53%)
# ilość mężczyzn: 314542 (47%)

# %%
def normalise(i_x, I_x):
    L_I_x = [i_x["Liczba"][i]/np.sum(i_x["Liczba"]) for i in range(len(I_x))]
    L_I_x = L_I_x/ min(L_I_x)
    L_I_x = L_I_x/ np.sum(L_I_x)
    return L_I_x

# %%
first_name = np.zeros(n).astype(str)
last_name = np.zeros(n).astype(str)
gender = np.zeros(n).astype(str)

x = np.random.choice(["K", "M"], size=n, replace=True, p=[0.53, 0.47]) # dla odpowiedniego mianownika kobiet do mężczyzn
imiona_m = np.random.choice(I_m, size=n, replace=True, p=normalise(i_m, I_m))
imiona_k = np.random.choice(I_k, size=n, replace=True, p=normalise(i_k, I_k))
nazwiska_m = np.random.choice(N_m, size=n, replace=True, p=normalise(n_m, N_m))
nazwiska_k = np.random.choice(N_k, size=n, replace=True, p=normalise(n_k, N_k))

for i in range(n):
    if x[i] == "K":
        first_name[i] = imiona_k[i] #random.choice(I_k)
        last_name[i] = nazwiska_k[i] #random.choice(N_k)
        gender[i] = "female"
    else:
        first_name[i] = imiona_m[i] #random.choice(I_m)
        last_name[i] = nazwiska_m[i] #random.choice(N_m)
        gender[i] = "male"

# %%
customer_id = range(1,n+1)
dict_customer = {'customer_id':customer_id, "first_name": first_name, "last_name": last_name, "gender": gender}
customer = pd.DataFrame(dict_customer)

# %%
customer #1329 osób
# Out:
#       customer_id first_name    last_name  gender
# 0               1        Ewa        Sapak  female
# 1               2      Jakub  Szczepański    male
# 2               3   Kateryna  Teliszewska  female
# 3               4       Nela       Dendys  female
# 4               5       Maja    Zdanowska  female
# ...           ...        ...          ...     ...
# 1324         1325       Nela     Zgierska  female
# 1325         1326     Maciej   Kuryshchuk    male
# 1326         1327  Kazimierz     Owczarek    male
# 1327         1328     Julian       Rozmus    male
# 1328         1329    Gabriel     Głowacki    male
#
# [1329 rows x 4 columns]

# %% [markdown]
# https://interaktywnie.com/biznes/artykuly/biznes/przeglad-ktora-poczta-e-mail-jest-najlepsza-16950

# %%
# liczby użytkowników danych poczt email
gmail = 8968134
wp = 6895602
onet = 4302509
interia = 2677345
o2 = 2855010
pwr = 21902

all_users = gmail+wp+onet+interia+o2+pwr

# wektor prawdopodobieństw
mail_probab = [gmail/all_users, wp/all_users, onet/all_users, interia/all_users, o2/all_users, pwr/all_users]
mail_probab = [round(i,4) for i in mail_probab]
mail_probab[3] = 0.1040

# %%
email = np.zeros(n).astype(str)


for i in range(n):
    
    x = random.choice(range(1,3))
    
    if x == 1:
        nazwa = customer["first_name"][i]
        y = random.choice(range(1,5))
        if y == 1:
            nazwa += "." + customer["last_name"][i]
        elif y == 2:
            nazwa += customer["last_name"][i]
        elif y == 3:
            nazwa += "." + customer["last_name"][i][0:random.choice(range(3,5))]
        else:
            nazwa += str(random.choice(range(100,10000)))
        
    else:
        nazwa = customer["last_name"][i] 
        y = random.choice(range(1,5))
        if y == 1:
            nazwa += "." + customer["first_name"][i]
        elif y == 2:
            nazwa += customer["first_name"][i]
        elif y == 3:
            nazwa += "." + customer["first_name"][i][0:random.choice(range(2,5))]
        else:
            nazwa += str(random.choice(range(100,10000)))
        
    email[i] = nazwa
    
    
domeny = ["@gmail.com", "@wp.pl", "@onet.pl", "@interia.pl", "@o2.pl", "@student.pwr.edu.pl"]
domena = np.random.choice(domeny, size=len(email), replace=True, p=mail_probab)    

for i in range(n):
    email[i] += domena[i]
email = [unidecode(i) for i in email]

# %% [markdown]
# https://pl.wikipedia.org/wiki/Numery_telefoniczne_w_Polsce

# %%
phone = np.zeros(n).astype(int)
for i in range(n):
    number =  str(np.random.choice([45, 50, 51, 53, 57, 60, 66, 69, 72, 73, 78, 79, 88])) + str(random.choice(range(1000000, 9000000)))
    phone[i] = int(number)
customer["phone"] = phone
customer["email"] = email
customer
# Out:
#       customer_id first_name    last_name  gender      phone  \
# 0               1        Ewa        Sapak  female  791491634
# 1               2      Jakub  Szczepański    male  792370041
# 2               3   Kateryna  Teliszewska  female  663017148
# 3               4       Nela       Dendys  female  734919744
# 4               5       Maja    Zdanowska  female  577698695
# ...           ...        ...          ...     ...        ...
# 1324         1325       Nela     Zgierska  female  503904401
# 1325         1326     Maciej   Kuryshchuk    male  538455331
# 1326         1327  Kazimierz     Owczarek    male  781806955
# 1327         1328     Julian       Rozmus    male  535851916
# 1328         1329    Gabriel     Głowacki    male  692315852
#
#                          email
# 0            Ewa.Sap@gmail.com
# 1     Szczepanski.Ja@gmail.com
# 2           Kateryna8885@wp.pl
# 3          Dendys.Ne@gmail.com
# 4        MajaZdanowska@onet.pl
# ...                        ...
# 1324        Zgierska7432@wp.pl
# 1325      Maciej.Kur@gmail.com
# 1326  Kazimierz.Owczarek@wp.pl
# 1327      Julian4145@gmail.com
# 1328    Glowacki3891@gmail.com
#
# [1329 rows x 6 columns]

# %%
counter = Counter(phone)
result = [i for i, j in counter.items() if j > 1]
if result != []:
    print("Te same numery telefonu!!")
else:
    print("phone: Wszystko ok.")
    
counter = Counter(last_name)
result = [i for i, j in counter.items() if j > 1]
if result != []:
    print("Te same nazwiska!!")
else:
    print("last_name: Wszystko ok.")
# Out:
# phone: Wszystko ok.
# Te same nazwiska!!

# %%
print(counter)
# Out:
# Counter({'Nowak': 8, 'Kwiatkowska': 6, 'Kowalczyk': 6, 'Kowalski': 5, 'Szewczyk': 5, 'Woźniak': 4, 'Walczak': 4, 'Wiśniewska': 4, 'Kowalska': 4, 'Wieczorek': 3, 'Lis': 3, 'Mazur': 3, 'Trawińska': 3, 'Malinowska': 3, 'Janus': 3, 'Krawczyk': 3, 'Maćkowiak': 3, 'Pawłowska': 3, 'Dąbrowska': 3, 'Gil': 3, 'Wysocki': 3, 'Kozłowska': 3, 'Jędrzejewski': 3, 'Szczepański': 2, 'Wojnar': 2, 'Góra': 2, 'Bąk': 2, 'Polak': 2, 'Kwiatkowski': 2, 'Głuch': 2, 'Małecki': 2, 'Przybyła': 2, 'Kozicka': 2, 'Król': 2, 'Stec': 2, 'Michalski': 2, 'Majda': 2, 'Weber': 2, 'Krzewska': 2, 'Pawlikowski': 2, 'Gromek': 2, 'Kozieł': 2, 'Jankowska': 2, 'Bobrek': 2, 'Barańska': 2, 'Stankiewicz': 2, 'Chojnacka': 2, 'Bujanowski': 2, 'Zawadzka': 2, 'Kasperek': 2, 'Dudek': 2, 'Pietrzak': 2, 'Kołodziej': 2, 'Przybylski': 2, 'Kopacz': 2, 'Zych': 2, 'Janicka': 2, 'Czarnecka': 2, 'Domańska': 2, 'Kamińska': 2, 'Kramarz': 2, 'Stanisławski': 2, 'Kasprzak': 2, 'Wnuk': 2, 'Wróbel': 2, 'Dukat': 2, 'Zielińska': 2, 'Gruszczyńska': 2, 'Adamczyk': 2, 'Fabisiak': 2, 'Grzywa': 2, 'Adamiak': 2, 'Kaczmarek': 2, 'Wójcik': 2, 'Maziarz': 2, 'Olchawa': 2, 'Wasielewska': 2, 'Czapiewski': 2, 'Stenka': 2, 'Lewandowski': 2, 'Musiał': 2, 'Bogusz': 2, 'Woźnica': 2, 'Serafin': 2, 'Majchrzak': 2, 'Adamiec': 2, 'Kołodziejczyk': 2, 'Nowakowska': 2, 'Mrowiec': 2, 'Sulikowski': 2, 'Bogdański': 2, 'Markiewicz': 2, 'Murawski': 2, 'Witkowska': 2, 'Kopeć': 2, 'Łukaszewicz': 2, 'Januszewski': 2, 'Sapak': 1, 'Teliszewska': 1, 'Dendys': 1, 'Zdanowska': 1, 'Polishchuk': 1, 'Opyd': 1, 'Wiatrak': 1, 'Morina': 1, 'Kikosicka': 1, 'Pazuła': 1, 'Pałucka': 1, 'Guzy': 1, 'Nahlik': 1, 'Kowolik': 1, 'Szklarek': 1, 'Zaks': 1, 'Szczepańska': 1, 'Jarosiński': 1, 'Rosa': 1, 'Drewniak': 1, 'Radlica': 1, 'Łysikowska': 1, 'Donajkowska': 1, 'Szczerba': 1, 'Górzyńska': 1, 'Cielebąk': 1, 'Kopania': 1, 'Dąbkowska': 1, 'Giża': 1, 'Prejbisz': 1, 'Jastrzębska': 1, 'Biegańska': 1, 'Zachary': 1, 'Walis': 1, 'Szostak': 1, 'Durlik': 1, 'Brzykcy': 1, 'Dzik': 1, 'Czup': 1, 'Nawacki': 1, 'Markowicz': 1, 'Staśkowiak': 1, 'Biełaniec': 1, 'Czerwieniec': 1, 'Niedźwiedź': 1, 'Kasino': 1, 'Maziara': 1, 'Stachoń': 1, 'Koczan': 1, 'Wawer': 1, 'Bartkowiak': 1, 'Wagstyl': 1, 'Żarski': 1, 'Szymański': 1, 'Białas': 1, 'Belica': 1, 'Kryczka': 1, 'Jodkiewicz': 1, 'Sajdak': 1, 'Włodarczyk': 1, 'Pruszyński': 1, 'Wawrzyn': 1, 'Górzyński': 1, 'Białobłocka': 1, 'Gawlak': 1, 'Dziamska': 1, 'Lesińska': 1, 'Pasierbiewicz': 1, 'Gracz': 1, 'Piastowska': 1, 'Lisicka': 1, 'Szkudelski': 1, 'Buchta': 1, 'Gzyl': 1, 'Brzęcka': 1, 'Płachecki': 1, 'Hlynskyi': 1, 'Oryszczak': 1, 'Kwaśnica': 1, 'Waścinski': 1, 'Gul': 1, 'Wnęk': 1, 'Trzcianka': 1, 'Karaś': 1, 'Makówka': 1, 'Trzeciak': 1, 'Chludzińska': 1, 'Machałek': 1, 'Bronikowski': 1, 'Wołczański': 1, 'Jeżowska': 1, 'Pradun': 1, 'Szubel': 1, 'Zawacki': 1, 'Cielniak': 1, 'Wojcieszak': 1, 'Niedbała': 1, 'Klejman': 1, 'Kliczek': 1, 'Balakowska': 1, 'Konowałek': 1, 'Fronczak': 1, 'Głuszyk': 1, 'Krzykowska': 1, 'Telega': 1, 'Grochola': 1, 'Niewiadomski': 1, 'Kłoda': 1, 'Cierniewski': 1, 'Sosenka': 1, 'Kuza': 1, 'Zygmunt': 1, 'Pater': 1, 'Warmuz': 1, 'Marciniak': 1, 'Baran': 1, 'Grobis': 1, 'Włodarska': 1, 'Jaroch': 1, 'Szendzielorz': 1, 'Szklarski': 1, 'Fludra': 1, 'Ziob': 1, 'Wedman': 1, 'Dębiec': 1, 'Gąsior': 1, 'Dworak': 1, 'Lipka': 1, 'Superczyńska': 1, 'Pabian': 1, 'Haska': 1, 'Doburzyńska': 1, 'Pelzer': 1, 'Jeon': 1, 'Wolniewicz': 1, 'Makuch': 1, 'Glijer': 1, 'Łączyński': 1, 'Pijanowski': 1, 'Nechyporenko': 1, 'Kurzawa': 1, 'Pala': 1, 'Istrati': 1, 'Lech': 1, 'Pyzik': 1, 'Tabor': 1, 'Sendyk': 1, 'Moskal': 1, 'Nagrodzka': 1, 'Lorbiecka': 1, 'Kocjan': 1, 'Schabek': 1, 'Kozioł': 1, 'Szmit': 1, 'Bobowski': 1, 'Budrewicz': 1, 'Kłopotek': 1, 'Dendewicz': 1, 'Michalczuk': 1, 'Bikowska': 1, 'Sobiecki': 1, 'Oszczak': 1, 'Mańkowska': 1, 'Skomorucha': 1, 'Wiktorowicz': 1, 'Prus': 1, 'Filipecki': 1, 'Lach': 1, 'Grochulski': 1, 'Banasiak': 1, 'Dziunycz': 1, 'Turalska': 1, 'Hamryszak': 1, 'Lendzioszek': 1, 'Lachowska': 1, 'Prusak': 1 ...

# %%
#customer = customer.drop('', axis=1)
customer.reset_index(drop=False, inplace=False)

customer
# Out:
#       customer_id first_name    last_name  gender      phone  \
# 0               1        Ewa        Sapak  female  791491634
# 1               2      Jakub  Szczepański    male  792370041
# 2               3   Kateryna  Teliszewska  female  663017148
# 3               4       Nela       Dendys  female  734919744
# 4               5       Maja    Zdanowska  female  577698695
# ...           ...        ...          ...     ...        ...
# 1324         1325       Nela     Zgierska  female  503904401
# 1325         1326     Maciej   Kuryshchuk    male  538455331
# 1326         1327  Kazimierz     Owczarek    male  781806955
# 1327         1328     Julian       Rozmus    male  535851916
# 1328         1329    Gabriel     Głowacki    male  692315852
#
#                          email
# 0            Ewa.Sap@gmail.com
# 1     Szczepanski.Ja@gmail.com
# 2           Kateryna8885@wp.pl
# 3          Dendys.Ne@gmail.com
# 4        MajaZdanowska@onet.pl
# ...                        ...
# 1324        Zgierska7432@wp.pl
# 1325      Maciej.Kur@gmail.com
# 1326  Kazimierz.Owczarek@wp.pl
# 1327      Julian4145@gmail.com
# 1328    Glowacki3891@gmail.com
#
# [1329 rows x 6 columns]

# %%
customer.to_csv("customer.csv", sep = ",", encoding='utf-8-sig')

# %% [markdown]
# # staff table

# %% [raw]
# 20 pracowników ma być

# %%
random.seed(123)
n = 17 #ilość pracowników

# %%
first_name = np.zeros(n).astype(str)
last_name = np.zeros(n).astype(str)
gender = np.zeros(n).astype(str)

x = np.random.choice(["K", "M"], size=n, replace=True, p=[0.35, 0.65]) # chcemy więcej mężczyzn jako pracowników
imiona_m = np.random.choice(I_m, size=n, replace=True, p=normalise(i_m, I_m))
imiona_k = np.random.choice(I_k, size=n, replace=True, p=normalise(i_k, I_k))
nazwiska_m = np.random.choice(N_m, size=n, replace=True, p=normalise(n_m, N_m))
nazwiska_k = np.random.choice(N_k, size=n, replace=True, p=normalise(n_k, N_k))

for i in range(n):
    if x[i] == "K":
        first_name[i] = imiona_k[i] #random.choice(I_k)
        last_name[i] = nazwiska_k[i] #random.choice(N_k)
        gender[i] = "female"
    else:
        first_name[i] = imiona_m[i] #random.choice(I_m)
        last_name[i] = nazwiska_m[i] #random.choice(N_m)
        gender[i] = "male"

# %%
staff_id = range(1,n+1)
dict_staff = {'staff_id': staff_id, "first_name": first_name, "last_name": last_name, "gender": gender}
staff = pd.DataFrame(dict_staff)
staff
# Out:
#     staff_id   first_name    last_name  gender
# 0          1       Witold  Krzepkowski    male
# 1          2      Oliwier     Łabuński    male
# 2          3       Błażej     Janowski    male
# 3          4       Wiktor      Małecki    male
# 4          5     Beniamin    Renkowski    male
# 5          6       Marcel   Kostrubiec    male
# 6          7     Wojciech  Antosiewicz    male
# 7          8  Maksymilian     Ignaczak    male
# 8          9  Maksymilian     Mendrala    male
# 9         10      Mikołaj    Lebiodzik    male
# 10        11       Teodor        Czuba    male
# 11        12   Aleksander   Ziembański    male
# 12        13      Martyna  Adamkiewicz  female
# 13        14        Laura    Kasperska  female
# 14        15     Jonathan   Wiśniewski    male
# 15        16       Tereza        Figat  female
# 16        17        Laura        Kępka  female

# %%
# liczby użytkowników danych poczt email
gmail = 8968134
wp = 6895602
onet = 4302509
interia = 2677345
o2 = 2855010

all_users = gmail+wp+onet+interia+o2

# wektor prawdopodobieństw
mail_probab = [gmail/all_users, wp/all_users, onet/all_users, interia/all_users, o2/all_users]
mail_probab = [round(i,4) for i in mail_probab]
mail_probab = [i/min(mail_probab) for i in mail_probab]
mail_probab = mail_probab/np.sum(mail_probab)

# %%
email = np.zeros(n).astype(str)
for i in range(n):
    email[i] = staff["first_name"][i] + "." + staff["last_name"][i] + "@dragons.com"
email = [unidecode(i) for i in email]

# %%
phone = np.zeros(n).astype(int)
for i in range(n):
    number =  str(np.random.choice([45, 50, 51, 53, 57, 60, 66, 69, 72, 73, 78, 79, 88])) + str(random.choice(range(1000000, 9000000)))
    phone[i] = int(number)
staff["phone"] = phone
staff["email"] = email
staff

amount = [4310, 5140, 6530, 7280, 8320] #ceny brutto
salary = np.random.choice(amount, size=n, replace=True, p=[0.35, 0.35, 0.15, 0.10, 0.05]). astype(float)
staff["salary"] = salary 
staff
# Out:
#     staff_id   first_name    last_name  gender      phone  \
# 0          1       Witold  Krzepkowski    male  531439257
# 1          2      Oliwier     Łabuński    male  883245438
# 2          3       Błażej     Janowski    male  511731374
# 3          4       Wiktor      Małecki    male  607450473
# 4          5     Beniamin    Renkowski    male  794416191
# 5          6       Marcel   Kostrubiec    male  883236015
# 6          7     Wojciech  Antosiewicz    male  501903455
# 7          8  Maksymilian     Ignaczak    male  668033877
# 8          9  Maksymilian     Mendrala    male  608559804
# 9         10      Mikołaj    Lebiodzik    male  458338570
# 10        11       Teodor        Czuba    male  501320056
# 11        12   Aleksander   Ziembański    male  534180325
# 12        13      Martyna  Adamkiewicz  female  575497988
# 13        14        Laura    Kasperska  female  795717071
# 14        15     Jonathan   Wiśniewski    male  693786676
# 15        16       Tereza        Figat  female  733858822
# 16        17        Laura        Kępka  female  608147820
#
#                                email  salary
# 0     Witold.Krzepkowski@dragons.com  6530.0
# 1       Oliwier.Labunski@dragons.com  5140.0
# 2        Blazej.Janowski@dragons.com  5140.0
# 3         Wiktor.Malecki@dragons.com  5140.0
# 4     Beniamin.Renkowski@dragons.com  5140.0
# 5      Marcel.Kostrubiec@dragons.com  6530.0
# 6   Wojciech.Antosiewicz@dragons.com  5140.0
# 7   Maksymilian.Ignaczak@dragons.com  4310.0
# 8   Maksymilian.Mendrala@dragons.com  5140.0
# 9      Mikolaj.Lebiodzik@dragons.com  4310.0
# 10          Teodor.Czuba@dragons.com  5140.0
# 11  Aleksander.Ziembanski@dragons.co  4310.0
# 12   Martyna.Adamkiewicz@dragons.com  6530.0
# 13       Laura.Kasperska@dragons.com  5140.0
# 14   Jonathan.Wisniewski@dragons.com  4310.0
# 15          Tereza.Figat@dragons.com  5140.0
# 16           Laura.Kepka@dragons.com  5140.0

# %%
staff.to_csv("staff.csv", sep = ",", encoding='utf-8-sig')
